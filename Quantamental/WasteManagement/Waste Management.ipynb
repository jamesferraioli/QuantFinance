# %%
import pandas as pd

# %%
landfill_data = pd.read_csv("Landfill_Data.csv")

# %%
import matplotlib.pyplot as plt

# %%
landfill_data
# Out:
#        GHGRP_ID Landfill_ID  \
# 0     1001633.0          23
# 1     1006790.0           7
# 2     1006790.0           7
# 3     1001297.0       10860
# 4           NaN          27
# 5           NaN          16
# 6     1004245.0        2005
# 7           NaN        2006
# 8     1004415.0        2408
# 9           NaN           6
# 10    1007813.0           8
# 11          NaN        2409
# 12    1010661.0           2
# 13    1010661.0           2
# 14    1010661.0           2
# 15    1010661.0           2
# 16    1010661.0           2
# 17    1010957.0          19
# 18    1006186.0           9
# 19          NaN           3
# 20    1007382.0           4
# 21    1007018.0          15
# 22          NaN          35
# 23          NaN          34
# 24    1005839.0          11
# 25          NaN          10
# 26    1004014.0          25
# 27    1005680.0          13
# 28    1007875.0          20
# 29          NaN          31
# ...         ...         ...
# 3145        NaN        1693
# ...

# %%
wm = pd.DataFrame(landfill_data[landfill_data['Landfill_Owner_Organization'] == 'Waste_Management,_Inc.'])

# %%
wm
# Out:
#        GHGRP_ID Landfill_ID                                    Landfill_Name  \
# 36    1003265.0          17                                   Salem_Landfill
# 47          NaN          33                                  Valley_View_SLF
# 52    1010389.0       11941                        Capitol_Disposal_Landfill
# 62    1007815.0        1783                     Butterfield_Station_Landfill
# 63    1007815.0        1783                     Butterfield_Station_Landfill
# 76    1007862.0        2194                      Gray_Wolf_Regional_Landfill
# 79    1003612.0        2391                                Ironwood_Landfill
# 82    1007543.0       12205                             Lone_Cactus_Landfill
# 87    1000031.0        1786                  Northwest_Regional_MSW_Landfill
# 88    1003611.0        1771                          Painted_Desert_Landfill
# 94          NaN        2392                         Sierra_Estrella_Landfill
# ...

# %%
wm_open = pd.DataFrame(wm[wm['Current_Landfill_Status'] == 'Open'])

# %%
wm_open
# Out:
#        GHGRP_ID Landfill_ID                                    Landfill_Name  \
# 36    1003265.0          17                                   Salem_Landfill
# 52    1010389.0       11941                        Capitol_Disposal_Landfill
# 62    1007815.0        1783                     Butterfield_Station_Landfill
# 63    1007815.0        1783                     Butterfield_Station_Landfill
# 76    1007862.0        2194                      Gray_Wolf_Regional_Landfill
# 87    1000031.0        1786                  Northwest_Regional_MSW_Landfill
# 88    1003611.0        1771                          Painted_Desert_Landfill
# 94          NaN        2392                         Sierra_Estrella_Landfill
# 110   1003406.0        2282                               Eco-Vista_Landfill
# 124   1007681.0        2284                             Ozark_Ridge_Landfill
# 128   1007896.0        2043                                Two_Pine_Landfill
# ...

# %%
wm = wm_open

# %%
wm
# Out:
#        GHGRP_ID Landfill_ID                                    Landfill_Name  \
# 36    1003265.0          17                                   Salem_Landfill
# 52    1010389.0       11941                        Capitol_Disposal_Landfill
# 62    1007815.0        1783                     Butterfield_Station_Landfill
# 63    1007815.0        1783                     Butterfield_Station_Landfill
# 76    1007862.0        2194                      Gray_Wolf_Regional_Landfill
# 87    1000031.0        1786                  Northwest_Regional_MSW_Landfill
# 88    1003611.0        1771                          Painted_Desert_Landfill
# 94          NaN        2392                         Sierra_Estrella_Landfill
# 110   1003406.0        2282                               Eco-Vista_Landfill
# 124   1007681.0        2284                             Ozark_Ridge_Landfill
# 128   1007896.0        2043                                Two_Pine_Landfill
# ...

# %%
open_landfills = pd.DataFrame(landfill_data[landfill_data['Current_Landfill_Status'] == 'Open'])open_landfills_ex_wm = pd.DataFrame(open_landfills[open_landfills['Landfill_Owner_Organization'] != 'Waste_Management,_Inc.'])

# %%
advanced_disposal = pd.DataFrame(open_landfills[open_landfills['Landfill_Owner_Organization'] == 'Advanced_Disposal_Services'])

# %%
advanced_disposal
# Out:
#        GHGRP_ID Landfill_ID  \
# 0     1001633.0          23
# 1     1006790.0           7
# 2     1006790.0           7
# 43    1006183.0       11581
# 46    1011271.0       11982
# 697   1001636.0         458
# 729   1003710.0       10403
# 788   1003711.0       10404
# 841   1001637.0        1899
# 842   1006963.0         501
# 843   1006963.0         501
# 844   1005985.0         494
# 845   1005985.0         494
# 954   1001639.0         532
# 955   1007983.0         561
# 1143  1001642.0         685
# 1148  1004082.0         674
# 1149  1004082.0         674
# 1365  1008034.0        1879
# 1366  1008034.0        1879
# 1539  1003038.0         892
# 2317  1001844.0        1277
# 2318  1001643.0        1288
# 2319  1001643.0        1288
# 2320  1004321.0        1258
# 2339  1004162.0        1260
# 2398  1004164.0        1297
# 2399  1004164.0        1297
# 2400  1004164.0        1297
# 2436  1002716.0        1271
# 2583  1011487.0        1436
# 3086  1001845.0        1702
# ...

# %%
open_landfills_ex_wm = pd.DataFrame(open_landfills[open_landfills['Landfill_Owner_Organization'] != 'Waste_Management,_Inc.'])

# %%
open_landfills_ex_wm_adsw = pd.DataFrame(open_landfills_ex_wm[open_landfills_ex_wm['Landfill_Owner_Organization'] != 'Advanced_Disposal_Services'])

# %%
len(open_landfills)
# Out:
# 1678

# %%
len(open_landfills_ex_wm_adsw)
# Out:
# 1387

# %%
1678-1387
# Out:
# 291

# %%
len(wm)
# Out:
# 250

# %%
wm_merged = wm.append(advanced_disposal)

# %%
len(wm_merged)
# Out:
# 291

# %% [markdown]
# wm_merged

# %%
import plotly.express as px

fig = px.scatter_mapbox(wm_merged, lat=wm_merged.Latitude, lon=wm_merged.Longitude)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-0a9d1d02eba1> in <module>()
#       1 import plotly.express as px
#       2
# ----> 3 fig = px.scatter_mapbox(wm_merged, lat=wm_merged.Latitude, lon=wm_merged.Longitude)
#       4 fig.show()
#
# ~\Anaconda3\lib\site-packages\plotly\express\_chart_types.py in scatter_mapbox(data_frame, lat, lon, color, text, hover_name, hover_data, size, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, opacity, size_max, zoom, title, template, width, height)
#     942     In a Mapbox scatter plot, each row of `data_frame` is represented by a symbol mark on a Mapbox map.
#     943     """
# --> 944     return make_figure(args=locals(), constructor=go.Scattermapbox)
#     945
#     946
#
# ...

# %%
wm_merged
# Out:
#        GHGRP_ID Landfill_ID  \
# 36    1003265.0          17
# 52    1010389.0       11941
# 62    1007815.0        1783
# 63    1007815.0        1783
# 76    1007862.0        2194
# 87    1000031.0        1786
# 88    1003611.0        1771
# 94          NaN        2392
# 110   1003406.0        2282
# 124   1007681.0        2284
# 128   1007896.0        2043
# 138   1007699.0          39
# 139   1007699.0          39
# 140   1007699.0          39
# 147   1007839.0          45
# 149   1007710.0          47
# 244   1007794.0       12146
# 259   1007693.0         147
# 280   1007837.0         164
# 310   1007817.0         188
# 315   1007841.0         314
# 416   1007668.0         258
# 417   1007668.0         258
# 443   1007816.0         279
# 522         NaN        2393
# 524   1008019.0        1720
# 540   1007863.0        1722
# 544   1007880.0        1738
# 648   1007857.0         402
# 649   1007856.0         397
# ...         ...         ...
# 844   1005985.0         494
# ...

# %%
import plotly.graph_objects as go
import pandas as pd

fig = go.Figure(data=go.Scattergeo(
        lon = wm_merged.Longitude,
        lat = wm_merged.Latitude,
        mode = 'markers',
        ))

fig.update_layout(
        title = 'Open Waste Management and Advanced Disposal Services Landfills',
        geo_scope='usa',
    )
fig.show()
# Out:
# <div>
#
#
#             <div id="8b96f29c-b82c-4775-be74-371499c01ee3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8b96f29c-b82c-4775-be74-371499c01ee3")) {
#                     Plotly.newPlot(
#                         '8b96f29c-b82c-4775-be74-371499c01ee3',
# ...

# %%
import plotly.graph_objects as go
import pandas as pd

fig = go.Figure(data=go.Scattergeo(
        lon = wm_merged.Longitude,
        lat = wm_merged.Latitude,
        mode = 'markers',
        ))

fig.update_layout(
        title = 'Open Waste Management and Advanced Disposal Services Landfills',
        geo_scope='usa',
    )

fig2 = go.Figure(data=go.Scattergeo(
        lon = open_landfills_ex_wm_adsw.Longitude,
        lat = open_landfills_ex_wm_adsw.Latitude,
        mode = 'markers',
        ))

fig2.update_layout(
        title = 'Open Landfills excluding Waste Management and Advanced Disposal Services',
        geo_scope='usa',
    )
fig.show(), fig2.show()
# Out:
# <div>
#
#
#             <div id="8447236f-e732-45e0-9098-fce3cbcf5b68" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8447236f-e732-45e0-9098-fce3cbcf5b68")) {
#                     Plotly.newPlot(
#                         '8447236f-e732-45e0-9098-fce3cbcf5b68',
# ...

# %%
open_landfills
# Out:
#        GHGRP_ID Landfill_ID  \
# 0     1001633.0          23
# 1     1006790.0           7
# 2     1006790.0           7
# 3     1001297.0       10860
# 6     1004245.0        2005
# 8     1004415.0        2408
# 10    1007813.0           8
# 12    1010661.0           2
# 13    1010661.0           2
# 14    1010661.0           2
# 15    1010661.0           2
# 16    1010661.0           2
# 17    1010957.0          19
# 18    1006186.0           9
# 20    1007382.0           4
# 21    1007018.0          15
# 24    1005839.0          11
# 26    1004014.0          25
# 27    1005680.0          13
# 28    1007875.0          20
# 30    1002464.0        2011
# 31    1006028.0          14
# 32    1006028.0          14
# 33    1006957.0          18
# 34    1006957.0          18
# 35    1002646.0          22
# 36    1003265.0          17
# 37    1006304.0        2410
# 39    1004860.0       11821
# 41    1007082.0           5
# ...         ...         ...
# 3122  1002208.0        1673
# ...

# %%
open_landfills.Ownership_Type.Public
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-a2dbed352a88> in <module>()
# ----> 1 open_landfills.Ownership_Type.Public
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'Public'

# %%
public_landfills = pd.DataFrame(open_landfills[open_landfills['Ownership_Type'] == 'Public'])

# %%
len(public_landfills)
# Out:
# 951

# %%
len(open_landfills)
# Out:
# 1678

# %%
951/1678
# Out:
# 0.566746126340882

# %%
US_garbage_production = 262400000

# %%
pop_growth = pd.read_csv("pop_growth.csv")

# %%
pop_growth
# Out:
#    Area  United_States  Northeast   Midwest      South      West  Alabama  \
# 0  2010      309326085   55380645  66974749  114867066  72103625  4785448
# 1  2011      311580009   55600532  67152631  116039399  72787447  4798834
# 2  2012      313874218   55776729  67336937  117271075  73489477  4815564
# 3  2013      316057727   55907823  67564135  118393244  74192525  4830460
# 4  2014      318386421   56015864  67752238  119657737  74960582  4842481
# 5  2015      320742673   56047587  67869139  121037542  75788405  4853160
# 6  2016      323071342   56058789  67996917  122401186  76614450  4864745
# 7  2017      325147121   56072676  68156035  123598424  77319986  4875120
# 8  2018      327167434   56111079  68308744  124753948  77993663  4887871
#
#    Alaska  Arizona  Arkansas     ...       Tennessee     Texas     Utah  \
# 0  713906  6407774   2921978     ...         6355301  25242679  2775334
# 1  722038  6473497   2940407     ...         6397410  25646227  2814216
# ...

# %%
pop_growth.United_States.pct_change()
# Out:
# 0         NaN
# 1    0.007287
# 2    0.007363
# 3    0.006957
# 4    0.007368
# 5    0.007401
# 6    0.007260
# 7    0.006425
# 8    0.006214
# Name: United_States, dtype: float64

# %%
pop_growth_rate = pop_growth.United_States.pct_change()

# %%
pop_growth_rate.mean()
# Out:
# 0.007034225740411654

# %%
adsw_transfer_stations = 73

# %%
wm_transfer_station = 314

# %%
merged_transfer_stations = adsw_transfer_stations + wm_transfer_station

# %% [raw]
# merged_transfer_stations

# %%
merged_transfer_stations
# Out:
# 387

# %%
US_pop_2018 = pop_growth[pop_growth["Area"]==2018]

# %%
US_garbage_production / US_pop_2018.United_States
# Out:
# 8    0.802036
# Name: United_States, dtype: float64

# %%
US_pop_2018.United_States
# Out:
# 8    327167434
# Name: United_States, dtype: int64

# %%
US_garbage_production = US_garbage_production * 2000

# %%
US_garbage_production / US_pop_2018.United_States
# Out:
# 8    1604.071633
# Name: United_States, dtype: float64

# %%
1604/365
# Out:
# 4.394520547945206

# %% [markdown]
# wm_merged / open_landfills

# %%
len(wm_merged)
# Out:
# 291

# %%
len(open_landfills)
# Out:
# 1678

# %%
291/1678
# Out:
# 0.1734207389749702

# %%
US_garbage_production_growth = []

# %%
1.007**10
# Out:
# 1.0722466684701684

# %%
US_garbage_production_growth = US_garbage_production*1.072

# %%
US_garbage_production_growth
# Out:
# 562585600000.0

# %%
US_garbage_production
# Out:
# 524800000000

# %%
US_garbage_production_growth / US_garbage_production
# Out:
# 1.072

# %%
US_garbage_production * .173
# Out:
# 90790400000.0

# %%
WM_capture = US_garbage_production * .173

# %%
WM_2018_rev = 14914000000

# %%
WM_capture_per_pound = WM_2018_rev / WM_capture

# %%
WM_capture_per_pound
# Out:
# 0.16426846891301283

# %%
WM_capture * .1642
# Out:
# 14907783680.000002

# %%
WM_2018_rev = WM_2018_rev + 1558000000

# %%
1558 * 1000000
# Out:
# 1558000000

# %%
WM_capture_per_pound = WM_2018_rev / WM_capture

# %%
WM_capture_per_pound = WM_2018_rev / WM_capture

# %%
WM_capture_per_pound
# Out:
# 0.18142887353729029

# %%
US_garbage_production * .007
# Out:
# 3673600000.0

# %%
3673600000 / 1000000
# Out:
# 3673.6

# %%
3673600000 * .18
# Out:
# 661248000.0

# %%
ann_rev_growth = (US_garbage_production * .007) * .18

# %%
ann_rev_growth
# Out:
# 661248000.0

# %%
ann_rev_growth / WM_2018_rev
# Out:
# 0.04014375910636231
